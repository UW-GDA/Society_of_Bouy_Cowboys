# %%
#Import all packages
import os
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import folium
import contextily as ctx
import scipy.stats
import scipy.interpolate
import tqdm
from pathlib import Path
import xarray as xr
import skgstat as skg
import seaborn as sns
import pysal
from pysal.explore import esda
from pysal.lib import weights
from splot.esda import moran_scatterplot
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from matplotlib_scalebar.scalebar import ScaleBar
import os
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import rasterio as rio
import rasterio.plot
from rasterio.warp import calculate_default_transform, reproject, Resampling
from matplotlib_scalebar.scalebar import ScaleBar

# %%
imagedir= f'{Path.home()}//Society_of_Bouy_Cowboys/Data/SAT_GeoTiff'
imagedir
nov20_id='IcyCape_201911201739_S1B_EW_50m.tif'
path_nov20= os.path.join(imagedir,nov20_id)
nov20_img= rio.open(path_nov20)
nov20_img.crs()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 6
#       4 path_nov20= os.path.join(imagedir,nov20_id)
#       5 nov20_img= rio.open(path_nov20)
# ----> 6 nov20_img.crs()
#
# TypeError: 'NoneType' object is not callable

# %%
import matplotlib.pyplot as plt
from rasterio.plot import show

fig, ax = plt.subplots(figsize=(8, 8))
show(nov20_img,ax=ax, cmap='gray')
ax.set_title('Icy Cape — Nov 20 2019')
plt.show()

# %%
with rio.open(path_nov20) as src:
    print(src.crs)
# Out:
# None
